# %%
import pymongo

# %%
client = pymongo.MongoClient('mongodb://process:ge6acuRa@ecosensedb02.cs.au.dk/ecosense' )

# %%
db = client.ecosense

# %%
HCY = db.HCYRE001

# %%
HCY.count()
# Out:
# 520238

# %%
HCY.find({'gpsLocations':{'$nin': [[],{}]}}).count()
# Out:
# 1 loops, best of 3: 10min 25s per loop

# %%
ite = HCY.find({'gpsLocations':{'$nin': [[],{}]}})

# %%
# %time ite.count()
# Out:
# CPU times: user 20.2 ms, sys: 14.3 ms, total: 34.5 ms
# Wall time: 10min 27s
# 198509

# %%
ite.collection.find(
# Out:
# ['_Cursor__as_class',
#  '_Cursor__batch_size',
#  '_Cursor__check_okay_to_chain',
#  '_Cursor__collection',
#  '_Cursor__comment',
#  '_Cursor__compile_re',
#  '_Cursor__connection_id',
#  '_Cursor__data',
#  '_Cursor__die',
#  '_Cursor__empty',
#  '_Cursor__exhaust',
#  '_Cursor__exhaust_mgr',
#  '_Cursor__explain',
#  '_Cursor__fields',
#  '_Cursor__hint',
#  '_Cursor__id',
#  '_Cursor__killed',
#  '_Cursor__kwargs',
#  '_Cursor__limit',
#  '_Cursor__manipulate',
#  '_Cursor__max',
#  '_Cursor__max_scan',
#  '_Cursor__max_time_ms',
#  '_Cursor__min',
#  '_Cursor__must_use_master',
#  '_Cursor__ordering',
#  '_Cursor__query_flags',
#  '_Cursor__query_options',
#  '_Cursor__query_spec',
#  '_Cursor__read_preference',
#  '_Cursor__retrieved',
#  '_Cursor__secondary_acceptable_latency_ms',
#  '_Cursor__send_message',
#  '_Cursor__skip',
#  '_Cursor__slave_okay',
#  '_Cursor__snapshot',
#  '_Cursor__spec',
#  '_Cursor__tag_sets',
#  '_Cursor__tz_aware',
#  '_Cursor__uuid_subtype',
# ...

# %%
ite['gpsLocations']
# Out:
# [{u'accuracy': 445.0647888183594,
#   u'altitude': 41.19497299194336,
#   u'bearing': 0.0,
#   u'hasAccuracy': True,
#   u'hasAltitude': True,
#   u'hasBearing': True,
#   u'hasNumberOfSatellites': False,
#   u'hasSpeed': False,
#   u'latitude': 56.32282118180574,
#   u'longitude': 8.710704630571794,
#   u'numberOfSatellites': 0,
#   u'speed': 0.0,
#   u'timestamp': 1401284381520L},
#  {u'accuracy': 445.564453125,
#   u'altitude': 41.19497299194336,
#   u'bearing': 0.0,
#   u'hasAccuracy': True,
#   u'hasAltitude': True,
#   u'hasBearing': True,
#   u'hasNumberOfSatellites': False,
#   u'hasSpeed': False,
#   u'latitude': 56.32272949771131,
#   u'longitude': 8.711455668418546,
#   u'numberOfSatellites': 0,
#   u'speed': 0.0,
#   u'timestamp': 1401284385454L},
#  {u'accuracy': 186.18714904785156,
#   u'altitude': 41.54830551147461,
#   u'bearing': 0.0,
#   u'hasAccuracy': True,
#   u'hasAltitude': True,
#   u'hasBearing': True,
#   u'hasNumberOfSatellites': False,
# ...
