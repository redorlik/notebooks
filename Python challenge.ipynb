# %%
2**38
# Out:
# 274877906944

# %%
st = "g fmnc wms bgblr rpylqjyrc gr zw fylb. rfyrq ufyr amknsrcpq ypc dmp. bmgle gr gl zw fylb gq glcddgagclr ylb rfyr'q ufw rfgq rcvr gq qm jmle. sqgle qrpgle.kyicrpylq() gq pcamkkclbcb. lmu ynnjw ml rfc spj."

# %%
import string

# %%
let = string.ascii_lowercase

# %%
sh_let = let[2:]+let[:2]
tr = string.maketrans(let,sh_let)
print type(tr)
# Out:
# <type 'str'>

# %%
res = st.translate(tr)

# %%
print res
# Out:
# i hope you didnt translate it by hand. thats what computers are for. doing it in by hand is inefficient and that's why this text is so long. using string.maketrans() is recommended. now apply on the url.

# %%
'map'.translate(tr)
# Out:
# 'ocr'

# %%
formatstreng = '{first} er den første parameter. {anden} er den anden.'
d = {'first':'Python','anden':'Viden'}
print formatstreng.format(**d)
# Out:
# Python er den første parameter. Viden er den anden.

# %%
formatstreng = '{0.first} er den første parameter. {0.anden} er den anden.'
class C:
    @property
    def first(self):
        return 'Python'

    @property
    def anden(self):
        return 'Viden'
print formatstreng.format(C())
# Out:
# Python er den første parameter. Viden er den anden.

# %%
ormatstreng = '{0} er den første parameter. {1} er den anden.'
tup = ('Python', 'Viden')
print ormatstreng.format(*('Python', 'Viden'))
# Out:
# Python er den første parameter. Viden er den anden.

# %%
form1 = """
\\stepcounter{pycounter}
\\begin{filecontents*}{%(chapter)s\\thepycounter.py}

\\end{filecontents*}

\\begin{formula1}
    {%(topic)s()}
    {}
    { 
    \\lstinputlisting[basicstyle=\\ttfamily]{%(chapter)s\\thepycounter.py}
    }
    {}
    {ref_%(chapter)s_%(topic)s}
\\end{formula1}
"""

# %%
fpath = "/Users/anderslehmann/projects/brug_syntaks_python/"
chaps = []
chapter=out=''
with open(fpath+'outline','r') as f:
    for topicline in f:
        if '#' in topicline: continue
        if topicline.startswith(' '):
            print >>out,form1 % {'chapter':chapter, 'topic':topicline.strip()}
        else:
            if out: out.close()

            chapter = topicline.strip()
            chaps.append(chapter)
            out = open(fpath+'Python/content/'+chapter.lower()+'.tex','a')

# %%
chaps
# Out:
# ['builtins',
#  'flow',
#  'classes',
#  'Sekventielle typer',
#  'lists',
#  'dicts',
#  'tuples',
#  'sets',
#  'strings',
#  '#    allokering',
#  '#        R\xc3\xa5 strenge',
#  '#        Klasse',
#  '#    format',
#  '#        % format',
#  '#            tuple arguments',
#  '#            dict arguments',
#  '#        {} format',
#  '#            numbererd arguments',
#  '#            dict',
#  '#            object',
#  '#        format specifiers',
#  '#    join',
#  '#    capitalize',
#  '#    casefold',
#  '#    center',
#  '#    count',
#  '#    encode',
#  '#    endswith',
#  '#    expandtabs',
#  '#    find',
#  '#    format_map',
#  '#    index',
#  '#    isalnum',
#  '#    isalpha',
#  '#    isdecimal',
#  '#    isdigit',
#  '#    isidentifier',
#  '#    islower',
#  '#    isnumeric',
#  '#    isprintable',
#  '#    isspace',
#  '#    istitle',
#  '#    isupper',
#  '#    ljust',
#  '#    lower',
#  '#    lstrip',
#  '#    maketrans',
#  '#    partition',
# ...

# %%
py_path = fpath +"/Python"
import os
i = j = 0
for f in os.listdir(py_path):
    if '.py' in f:
        i += 1
        if os.path.getsize(py_path+'/'+f) == 1:
            j += 1
            print f
print j, i
# Out:
# 12.5

# %%
with open('/Users/anderslehmann/projects/brug_syntaks_python/Python/14.py','rb') as f:
    x = f.read()

# %%
# %load_ext physics
# Out:
# Unit calculation and physics extensions activated.

# %%
a = 1 V

# %%
print "{:.2f}".format(a)
# Out:
# 1.00 V

# %%
v = 100 km/h

# %%
t = 4 s

# %%
a = v/t

# %%
a.convert('m/s**2')
a *= 2

# %%
v = 700 km/h

# %%
t = v/a
t.convert('s')
print t
# Out:
# 14 s

# %%
s = 0.5*a*t**2
s.convert('m')
print s
# Out:
# 1361.1111 m

# %%
h = 4.9 m/s**2

# %%
v = 9.81 m/s**2

# %%
a = sqrt(h**2+v**2)

# %%
a
# Out:
# 10.965678 m/s^2

# %%
v_s = 490 km/h

# %%
R = 1600 m

# %%
a = v_s**2/R

# %%
a.convert('m/s**2')
a
# Out:
# 11.578897 m/s^2

# %%
u'a'.encode('utf8')
# Out:
# 'a'

# %%
100000/(7.5e6/3600)
# Out:
# 48.0

# %%
256/8
# Out:
# 32.0

# %%
a = arange(100).reshape(20,5)
b = arange(5)
c = a*b
d = b * a
print c.size,d.size
# Out:
# 100 100

# %%
print c,d
# Out:
# [[  0   1   4   9  16]
#  [  0   6  14  24  36]
#  [  0  11  24  39  56]
#  [  0  16  34  54  76]
#  [  0  21  44  69  96]
#  [  0  26  54  84 116]
#  [  0  31  64  99 136]
#  [  0  36  74 114 156]
#  [  0  41  84 129 176]
#  [  0  46  94 144 196]
#  [  0  51 104 159 216]
#  [  0  56 114 174 236]
#  [  0  61 124 189 256]
#  [  0  66 134 204 276]
#  [  0  71 144 219 296]
#  [  0  76 154 234 316]
#  [  0  81 164 249 336]
#  [  0  86 174 264 356]
#  [  0  91 184 279 376]
#  [  0  96 194 294 396]] [[  0   1   4   9  16]
#  [  0   6  14  24  36]
#  [  0  11  24  39  56]
#  [  0  16  34  54  76]
#  [  0  21  44  69  96]
#  [  0  26  54  84 116]
#  [  0  31  64  99 136]
#  [  0  36  74 114 156]
#  [  0  41  84 129 176]
#  [  0  46  94 144 196]
#  [  0  51 104 159 216]
#  [  0  56 114 174 236]
#  [  0  61 124 189 256]
#  [  0  66 134 204 276]
#  [  0  71 144 219 296]
#  [  0  76 154 234 316]
#  [  0  81 164 249 336]
#  [  0  86 174 264 356]
#  [  0  91 184 279 376]
#  [  0  96 194 294 396]]

# %%
import pandas

# %%
data = pandas.read_table('/Users/anderslehmann/src/Z-dim/zRACM3p.out',header=10,sep='\s*')
data = data.set_index(u'TIME')

# %%
data.index
# Out:
# Index([12.0, 13.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 98.0, 99.0, 100.0, 101.0, 102.0, 103.0, 104.0, 105.0, 106.0, 107.0, 108.0, 109.0, 110.0, 111.0, 112.0, 113.0, 114.0, 115.0, 116.0, 117.0, 118.0, 119.0, 120.0, 121.0, 122.0, 123.0, 124.0, 125.0, 126.0, 127.0, 128.0, 129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0, 145.0, 146.0, 147.0, 148.0, 149.0, 150.0, 151.0, 152.0, 153.0, 154.0, 155.0, 156.0, 157.0, 158.0, 159.0, 160.0, 161.0, 162.0, 163.0, 164.0, 165.0, 1
# ...

# %%
for col in data.columns:

    data[col].plot(label=col)
    legend()
    figure()

# %%
len( data.columns)
# Out:
# 77

# %%
data.index
# Out:
# Index([12.0, 13.0, 14.0, 15.0, 16.0, 17.0, 18.0, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0, 26.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0, 33.0, 34.0, 35.0, 36.0, 37.0, 38.0, 39.0, 40.0, 41.0, 42.0, 43.0, 44.0, 45.0, 46.0, 47.0, 48.0, 49.0, 50.0, 51.0, 52.0, 53.0, 54.0, 55.0, 56.0, 57.0, 58.0, 59.0, 60.0, 61.0, 62.0, 63.0, 64.0, 65.0, 66.0, 67.0, 68.0, 69.0, 70.0, 71.0, 72.0, 73.0, 74.0, 75.0, 76.0, 77.0, 78.0, 79.0, 80.0, 81.0, 82.0, 83.0, 84.0, 85.0, 86.0, 87.0, 88.0, 89.0, 90.0, 91.0, 92.0, 93.0, 94.0, 95.0, 96.0, 97.0, 98.0, 99.0, 100.0, 101.0, 102.0, 103.0, 104.0, 105.0, 106.0, 107.0, 108.0, 109.0, 110.0, 111.0, 112.0, 113.0, 114.0, 115.0, 116.0, 117.0, 118.0, 119.0, 120.0, 121.0, 122.0, 123.0, 124.0, 125.0, 126.0, 127.0, 128.0, 129.0, 130.0, 131.0, 132.0, 133.0, 134.0, 135.0, 136.0, 137.0, 138.0, 139.0, 140.0, 141.0, 142.0, 143.0, 144.0, 145.0, 146.0, 147.0, 148.0, 149.0, 150.0, 151.0, 152.0, 153.0, 154.0, 155.0, 156.0, 157.0, 158.0, 159.0, 160.0, 161.0, 162.0, 163.0, 164.0, 165.0, 1
# ...
