# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('/Users/alehmann/Documents/Documents/HIH/BDA/BDA2017/data/kmeans/2015-05-26_17-11-46.csv')
data.index = data['loggingTime']
data
# Out:
#                                      loggingTime  loggingSample  \
# loggingTime
# 2015-05-26 17:11:47.040  2015-05-26 17:11:47.040              1
# 2015-05-26 17:11:47.121  2015-05-26 17:11:47.121              2
# 2015-05-26 17:11:47.126  2015-05-26 17:11:47.126              3
# 2015-05-26 17:11:47.131  2015-05-26 17:11:47.131              4
# 2015-05-26 17:11:47.134  2015-05-26 17:11:47.134              5
# 2015-05-26 17:11:47.137  2015-05-26 17:11:47.137              6
# 2015-05-26 17:11:47.140  2015-05-26 17:11:47.140              7
# 2015-05-26 17:11:47.209  2015-05-26 17:11:47.209              8
# 2015-05-26 17:11:47.213  2015-05-26 17:11:47.213              9
# 2015-05-26 17:11:47.216  2015-05-26 17:11:47.216             10
# 2015-05-26 17:11:47.221  2015-05-26 17:11:47.221             11
# 2015-05-26 17:11:47.225  2015-05-26 17:11:47.225             12
# 2015-05-26 17:11:47.249  2015-05-26 17:11:47.249             13
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
acc = data[['accelerometerAccelerationX','accelerometerAccelerationY','accelerometerAccelerationZ']]

# %%
model = KMeans(n_clusters=6)

# %%
model.fit(acc)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
model.cluster_centers_
# Out:
# array([[ 0.26433475, -0.14100853, -0.99490346],
#        [-0.00432577, -0.19349312, -1.02126626],
#        [ 0.13096201,  0.11757168, -1.05373503],
#        [ 0.00329741, -0.06544491, -1.0468468 ],
#        [ 0.47229389,  0.02493754, -0.96082945],
#        [ 0.24464642, -0.0352484 , -1.02148058]])

# %%
model.cluster_centers_
# Out:
# array([[ 0.26433475, -0.14100853, -0.99490346],
#        [-0.00432577, -0.19349312, -1.02126626],
#        [ 0.13096201,  0.11757168, -1.05373503],
#        [ 0.00329741, -0.06544491, -1.0468468 ],
#        [ 0.47229389,  0.02493754, -0.96082945],
#        [ 0.24464642, -0.0352484 , -1.02148058]])

# %%
res = model.predict(acc)

# %%
res
# Out:
# array([1, 1, 1, ..., 5, 5, 5], dtype=int32)

# %%
cluster_sizes = [len(res[res==x]) for x in range(6)]

# %%
cluster_sizes
# Out:
# [19163, 11700, 7952, 26187, 2782, 61897]

# %%
length_centers = [norm(x) for x in model.cluster_centers_]
length_centers
# Out:
# [1.0390327961191914,
#  1.039443636825337,
#  1.0683312530221107,
#  1.0488956710609521,
#  1.0709232646442759,
#  1.0509599858266832]

# %%
data['cluster'] = res

# %%
cluster_speed = data[['locationSpeed','cluster']]
cluster_speed
# Out:
#                          locationSpeed  cluster
# loggingTime
# 2015-05-26 17:11:47.040      -1.000000        1
# 2015-05-26 17:11:47.121      -1.000000        1
# 2015-05-26 17:11:47.126      -1.000000        1
# 2015-05-26 17:11:47.131      -1.000000        1
# 2015-05-26 17:11:47.134      -1.000000        1
# 2015-05-26 17:11:47.137      -1.000000        1
# 2015-05-26 17:11:47.140      -1.000000        1
# 2015-05-26 17:11:47.209      -1.000000        1
# 2015-05-26 17:11:47.213      -1.000000        1
# 2015-05-26 17:11:47.216      -1.000000        1
# 2015-05-26 17:11:47.221      -1.000000        1
# 2015-05-26 17:11:47.225      -1.000000        1
# 2015-05-26 17:11:47.249      -1.000000        1
# 2015-05-26 17:11:47.253      -1.000000        1
# 2015-05-26 17:11:47.260      -1.000000        1
# 2015-05-26 17:11:47.265      -1.000000        1
# 2015-05-26 17:11:47.268      -1.000000        1
# 2015-05-26 17:11:47.273      -1.000000        1
# ...

# %%
cluster_speed.plot(y='locationSpeed')

# %%
for i in range(6):
    cluster_speed[f'cluster{i}'] = cluster_speed['locationSpeed'][cluster_speed['cluster']==i]
    
cluster_speed
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                          locationSpeed  cluster  cluster0  cluster1  cluster2  \
# loggingTime
# 2015-05-26 17:11:47.040      -1.000000        1       NaN      -1.0       NaN
# 2015-05-26 17:11:47.121      -1.000000        1       NaN      -1.0       NaN
# 2015-05-26 17:11:47.126      -1.000000        1       NaN      -1.0       NaN
# 2015-05-26 17:11:47.131      -1.000000        1       NaN      -1.0       NaN
# 2015-05-26 17:11:47.134      -1.000000        1       NaN      -1.0       NaN
# 2015-05-26 17:11:47.137      -1.000000        1       NaN      -1.0       NaN
# ...

# %%
fig = cluster_speed.plot(y=['cluster0','cluster1','cluster2','cluster3','cluster4','cluster5'])
fig.figure.autofmt_xdate()

# %%
for i in range(6):
    print(cluster_speed[f'cluster{i}'].mean())
# Out:
# 8.32340887197
# 5.81686770658
# 10.1100633635
# 7.19949013652
# 6.1102003688
# 10.6386110175

# %%
cluster_speed.mean(numeric_only=True)
# Out:
# locationSpeed     9.037436
# cluster           3.290983
# cluster0          8.323409
# cluster1          5.816868
# cluster2         10.110063
# cluster3          7.199490
# cluster4          6.110200
# cluster5         10.638611
# dtype: float64

# %%
from sklearn.mixture import GaussianMixture

# %%
model = GaussianMixture(n_components=6)

# %%
model.fit(acc)
# Out:
# GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#         means_init=None, n_components=6, n_init=1, precisions_init=None,
#         random_state=None, reg_covar=1e-06, tol=0.001, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
res2 = model.predict(acc)

# %%
data['GMM'] = res2

# %%
arr = np.array(cluster_speed)
arr.shape
# Out:
# (129681, 9)

# %%
cluster_speed = data[['locationSpeed','GMM']]
speed = np.array(cluster_speed['locationSpeed'])

print(len(speed))
for i in range(6):
    speed_ = speed.copy()
    speed_[cluster_speed['GMM']!=i] = NaN
    print(len(speed))
    cluster_speed[f'GMM{i}'] = speed_
# Out:
# 129681
# 129681
# 129681
# 129681
# 129681
# 129681
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 129681

# %%
fig = cluster_speed.plot(y=['GMM0','GMM1','GMM2','GMM3','GMM4','GMM5'],legend=False)

fig.figure.autofmt_xdate()

# %%
import datetime as dt

# %%
trmp = dt.datetime(2017,1,21)

# %%
diff = dt.date(2021,1,21)-trmp.date()

# %%
diff.days
# Out:
# 1461
