# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
testfile = "/Users/alehmann/Documents/Documents/HIH/phd_application/papers/GPS_paper/out.json"

# %%
import json

# %%
with open(testfile,"r") as f:
    gps_data = f.read()

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://process:ge6acuRa@ecosensedb01.cs.au.dk/ecosense')

# %%
db = client.ecosense

# %%
res = db.HCYRE001.find_one({'$and':
    [{"gpsLocations.longitude":{'$gt':8.86,'$lt':9.016}},
    {"gpsLocations.latitude":{'$gt':56.097,'$lt':56.1632}},{'gpsLocations.1000':{"$exists": "true"}}]},{'gpsLocations':1   })

# %%
res
# Out:
# {u'_id': ObjectId('551b8677e4b0db136138d2d8'),
#  u'gpsLocations': [{u'accuracy': 7.0,
#    u'altitude': 105.0,
#    u'bearing': 9.0,
#    u'hasAccuracy': True,
#    u'hasAltitude': True,
#    u'hasBearing': True,
#    u'hasNumberOfSatellites': True,
#    u'hasSpeed': True,
#    u'latitude': 56.08390583,
#    u'longitude': 8.99854747,
#    u'numberOfSatellites': 3,
#    u'speed': 33.75370407104492,
#    u'timestamp': 1427866907035L},
#   {u'accuracy': 7.0,
#    u'altitude': 105.0,
#    u'bearing': 9.0,
#    u'hasAccuracy': True,
#    u'hasAltitude': True,
#    u'hasBearing': True,
#    u'hasNumberOfSatellites': True,
#    u'hasSpeed': True,
#    u'latitude': 56.08390583,
#    u'longitude': 8.99854747,
#    u'numberOfSatellites': 3,
#    u'speed': 33.75370407104492,
#    u'timestamp': 1427866907059L},
#   {u'accuracy': 7.0,
#    u'altitude': 105.0,
#    u'bearing': 9.0,
#    u'hasAccuracy': True,
#    u'hasAltitude': True,
#    u'hasBearing': True,
# ...

# %%
len(res['gpsLocations'])
# Out:
# 3986

# %%
class Kalman:
    def __init__(self,state,covarians,update):
        pass

# %%
with open('/Users/alehmann/Documents/Documents/HIH/phd_application/papers/GPS_paper/trace.csv','w') as f:
    for dat in res['gpsLocations']:
        f.write('{}, {} \n'.format(dat['latitude'],dat['longitude']))
